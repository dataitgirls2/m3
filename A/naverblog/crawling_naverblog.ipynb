# %%
import pandas as pd
import numpy as np
import warnings

# %%
df = pd.read_csv("sample.csv")
df
# Out:
#      수요미식회  서대문양꼬치  20170322  2017. 3. 22. 20:32\n\t  \
# 0    수요미식회  서대문양꼬치  20170322       2017. 4. 12. 0:00
# 1    수요미식회  서대문양꼬치  20170322      2017. 4. 21. 16:17
# 2    수요미식회  서대문양꼬치  20170322  2017. 4. 17. 14:44\n\t
# 3    수요미식회  서대문양꼬치  20170322      2017. 3. 18. 12:39
# 4    수요미식회  서대문양꼬치  20170322   2017. 4. 17. 0:59\n\t
# 5    수요미식회  서대문양꼬치  20170322      2017. 3. 22. 21:37
# 6    수요미식회  서대문양꼬치  20170322  2017. 3. 22. 20:00\n\t
# 7    수요미식회  서대문양꼬치  20170322   2017. 2. 20. 8:10\n\t
# 8    수요미식회  서대문양꼬치  20170322   2017. 4. 1. 10:56\n\t
# 9    수요미식회  서대문양꼬치  20170322    2017. 4. 6. 8:20\n\t
# 10   수요미식회  서대문양꼬치  20170322   2017. 2. 26. 0:20\n\t
# 11   수요미식회  서대문양꼬치  20170322        2017. 3. 2. 8:30
# 12   수요미식회  서대문양꼬치  20170322  2017. 4. 16. 11:16\n\t
# 13   수요미식회  서대문양꼬치  20170322       2017. 4. 5. 19:14
# 14   수요미식회  서대문양꼬치  20170322  2017. 4. 20. 15:50\n\t
# 15   수요미식회  서대문양꼬치  20170322   2017. 3. 7. 16:29\n\t
# 16   수요미식회  서대문양꼬치  20170322  2017. 3. 23. 10:19\n\t
# 17   수요미식회  서대문양꼬치  20170322   2017. 3. 30. 2:26\n\t
# 18   수요미식회  서대문양꼬치  20170322    2017. 3. 2. 1:14\n\t
# 19   수요미식회  서대문양꼬치  20170322   2017. 3. 23. 4:00\n\t
# 20   수요미식회  서대문양꼬치  20170322  2017. 3. 22. 23:39\n\t
# 21   수요미식회  서대문양꼬치  20170322   2017. 4. 9. 12:33\n\t
# 22   수요미식회  서대문양꼬치  20170322      2017. 3. 28. 13:56
# 23   수요미식회  서대문양꼬치  20170322  2017. 3. 23. 14:25\n\t
# 24   수요미식회  서대문양꼬치  20170322      2017. 3. 27. 20:02
# 25   수요미식회  서대문양꼬치  20170322   2017. 3. 23. 2:40\n\t
# 26   수요미식회  서대문양꼬치  20170322   2017. 4. 1. 15:16\n\t
# 27   수요미식회  서대문양꼬치  20170322       2017. 3. 24. 4:41
# 28   수요미식회  서대문양꼬치  20170322      2017. 3. 24. 18:18
# 29   수요미식회  서대문양꼬치  20170322      2017. 4. 15. 10:07
# ..     ...     ...       ...                     ...
# 305  수요미식회    바라티에  20170322      2017. 3. 21. 17:39
# 306  수요미식회    바라티에  20170322   2017. 4. 12. 8:46\n\t
# 8                                   연남동 수요미식회나온 서대문양꼬치
# 9                                     [홍대/연남동] 서대문 양꼬치
# 10                                    <연남동 맛집> 서대문 양꼬치
# 11                    연남동 중국집 : 서대문 양꼬치, 사천요리 맛있게 하는 집
# 12                           4월 둘째주(feat.서대문양꼬치&동남방앗간)
# 13                                         연남동 #서대문양꼬치
# 14   17-03 흥부자(금요일, 맛따라멋따라, 연남동 서대문양꼬치, 연남동 오디너리킴스펍...
# 15                                  [홍대맛집/양고기집] 서대문양꼬치
# 16   수요미식회(110회) 2017년 3월 22일 연남동 특집 바리티에 트리빠,나노하나 ...
# 17                                        수요미식회 서대문양꼬치
# 18                    연남동 조지기 | 미즈컨테이너 에스프레소부티크 서대문양꼬치
# 19                수요미식회 연남동 맛집리스트 - 바라티에, 서대문양꼬치, 나노하나
# 20            연남동 나노하나 대창전골, 바라티에 라구파스타, 서대문양꼬치 사천매운전골
# 21   연남동 맛집 - 서대문양꼬치 : 연남동 중국음식추천 / 디저트 - 푸하하크림빵 / ...
# 22                                          연남동 서대문양꼬치
# 23                     수요미식회 연남동! 나노하나 / 바라티에 / 서대문양꼬치
# 24                                       연남동 서대문양꼬치 가봄
# 25                수요미식회 연남동 중국식 요리집 사천매운전골 ~ 서대문양꼬치 위치
# 26            [서울연남동] 서대문양꼬치(수요미식회맛집)_사천매운양고기전골, 가지볶음밥
# 27   [170322 - TVN 수요미식회] 서대문양꼬치 / 서울특별시 마포구 연남동 맛집...
# 28                      성시경의 단골 소주집 연남동 사천매운전골집 서대문양꼬치
# 29                                    수요미식회 연남동 서대문양꼬치
# ..                                                 ...
# 305                                     Bon Appétit 63
# 306                                            2017 삼월
# 307                                     Bon Appétit 62
# 308                              (rinbyrin) 꽉찬 알찬 사진일기
# 309                    Cafe de ONE PIECE 3월 #한정 신상품 안내
# 310                        170322 tvN 수요미식회 110회 - 연남동
# 311                        #13. 로칸다몽로 / 랑빠스81: 달리는 수요일
# 312  지난 주 TV 맛집 2017.03.20~2017.03.26 / 백종원의3대천왕, 수...
# 313                                 원피스 배 피규어 깜찍이들 *_*
# 314                  [서울/마포구/동교동:홍대입구역] 20170216, 연남슈퍼
# 315                                             연남동 일기
# 316                                       이스트블루(1~61화)
# 317               도쿄여행 - 3day (20) 시부야 마루이 ① - 원피스 스토어
# 318         2014.07.04~2014.07.06 첫 도쿄 여행 첫 일본 여행 둘째 날
# 319                             해골 디자인 & 일러스트 (시각 디자인)
# 320                                  원피스 화별 정리 1화~324화
# 321                       Happy Birthday to mee- 02/24
# 322                                       벌써 3월말.. *일상
# 323                                         16마르잔, 연남동
# 324                                  수요미식회 연남동특집 맛집리스트
# 325                   수요미식회 연남동,서대문양꼬치 돼지고기가지요리,양고기전골.
# 326                                     연남동맛집 & 동교동맛집♥
# 327                                  수요미식회 110회 연남동 특집
# 328  TvN 수요미식회 3월 22일 파스타에 소주를 곁들이는 이탈리안 선술집(라구 파스타...
# 329                 도쿄 자유여행 #2. 강력추천! 도쿄 원피스타워X상디 레스토랑
# 330                            [수요미식회] 110회 연남동 미식가이드♡
# 331       수요미식회 연남동 특집 바라티에 - 트리빠와 라구 파스타가 무난했던 소소한 술집
# 332  일상 27 / 홍대 쌀국수맛집 리틀파파포 / 합정 카페 비포그레이 / 연남동 맛집 ...
# 333  일상 31 / 홍대정문 카페 fabrica / 연희동 카페 크림필즈 / 한남동 맛집...
# 334                                              일상 기록
#
# [335 rows x 5 columns]

# %%
df.columns=['프로그램','식당명','방영일','포스팅일','제목']
df.head()
# Out:
#     프로그램     식당명       방영일                    포스팅일  \
# 0  수요미식회  서대문양꼬치  20170322       2017. 4. 12. 0:00
# 1  수요미식회  서대문양꼬치  20170322      2017. 4. 21. 16:17
# 2  수요미식회  서대문양꼬치  20170322  2017. 4. 17. 14:44\n\t
# 3  수요미식회  서대문양꼬치  20170322      2017. 3. 18. 12:39
# 4  수요미식회  서대문양꼬치  20170322   2017. 4. 17. 0:59\n\t
#
#                                                   제목
# 0                    [연남동 / 서대문양꼬치] 수요미식회 양고기전골 맛집
# 1        [마포구 연남동 맛집] 수요미식회 중식로드 맛집 중국 느낌 충만 서대문양꼬치!
# 2  요즘 먹은것들 (3)가로수길카페/와인/연남 서대문양꼬치/홍대 아오이토리/스벅/삼성역...
# 3                       연남동 맛집 서대문 양꼬치 - 수요미식회 중식로드
# 4                                         연남동 서대문양꼬치

# %%
# from datetime import date

# broad_date = df['방영일']

# b_date = []

# for data in broad_date:
#     year = str(data)[:4]
#     month = str(data)[4:6]
#     day = str(data)[6:8]

#     b_date.append(date(int(year), int(month), int(day)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-30dd7776c870> in <module>()
#      10     day = str(data)[6:8]
#      11
# ---> 12     b_date.append(date(int(year), int(month), int(day)))
#      13
#
# ValueError: invalid literal for int() with base 10: '3-'

# %%
from datetime import date
f_date = date(2014, 7, 2)
l_date = date(2014, 7, 11)
delta = l_date - f_date
print(delta.days)
# Out:
# 9

# %%
from datetime import date

broad_date = df['방영일']

for data in broad_date:
    year = str(data)[:4]
    month = str(data)[4:6]
    day = str(data)[6:8]

    b_date = date(int(year), int(month), int(day))
print
    
#     broad_date.replacce(data, b_date)
    
# print(broad_date)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-6e4506d4e116> in <module>()
#       8     day = str(data)[6:8]
#       9
# ---> 10     b_date = date(int(year), int(month), int(day))
#      11
#      12     broad_date.replacce(data, b_date)
#
# ValueError: invalid literal for int() with base 10: '3-'
